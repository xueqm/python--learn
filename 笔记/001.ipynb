# %%
print("hello worldx.m.xc,xz.v.,")
# Out:
# hello worldx.m.xc,xz.v.,

# %% [markdown]
# #  数字类型
#  -数字常量
#     -asdasd
#
#
#     python

# %%
a = 121656
print(a)
# Out:
# 121656

# %%
a = 0b1010101
print(a//10)
# Out:
# 8

# %%
# wrwe
a =  45
b = bin(a)
print(b)
c = oct(a)
print(c)
# Out:
# 0b101101
# 0o55

# %%
a = 3.654648486e3
print(a)
# Out:
# 3654.648486

# %% [markdown]
# ##复数

# %%
a = '''asdnaslflkanknlksndglknslkg
asfa;m;msfa;fm'''
print(a)
# Out:
# asdnaslflkanknlksndglknslkg
# asfa;m;msfa;fm

# %%
def stu(*args):
    '''
    这是第一行
    这是第二行
    这是第三行
    '''
    print("this is hanshu stu")

# %%
print(help(stu))
print("*"*20)
print(stu.__doc__)
# Out:
# Help on function stu in module __main__:
#
# stu(*args)
#     这是第一行
#     这是第二行
#     这是第三行
#
# None
# ********************
#
#     这是第一行
#     这是第二行
#     这是第三行

# %% [markdown]
# # 变量作用域
# -

# %%
# Out:
#   File "<ipython-input-2-773e994f2bfd>", line 3
#     return g()
#          ^
# IndentationError: expected an indented block
